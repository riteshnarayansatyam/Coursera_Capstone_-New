# %% [markdown]
# Importing Data Using Panda

# %%
import pandas as pd
import numpy as np 
df = pd.read_csv ('LT23.csv')
print(df)
# Out:
#                             Name   latitude   longitude
# 0                  Aritesh Kumar  23.667000   86.933000
# 1                          Barti  37.773972 -122.431297
# 2                         Cvisal  37.541290  -77.434769
# 3                          Damit  29.749907  -95.358421
# 4                 Esarvesh Gupta  32.715736 -117.161087
# 5                         Fpriya  38.624691  -90.184776
# 6                 Gpreeti Sharma  29.854263   77.888000
# 7          Asudhanshu Srivastava  26.850000   80.949997
# 8                         Bmohit  12.972442   77.580643
# 9                Camit Manchanda  28.535517   77.391029
# 10         Dvimalesh Kumar Singh  26.850000   80.949997
# 11                      Esantosh  28.457523   77.026344
# 12                   Fankit Garg  28.535517   77.391029
# 13               Gsaurabh Mathur  28.538336  -81.379234
# 14             Hamit Kumar Gupta  31.683000   76.117000
# 15                Kgautam Baghel  25.432571   81.851311
# ...

# %% [markdown]
# Getting information about Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        39 non-null     object
#  1    latitude   39 non-null     float64
#  2    longitude  39 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.0+ KB

# %% [markdown]
# Getting Description about Data

# %%
df.describe()
# Out:
#         latitude   longitude
# count  39.000000   39.000000
# mean   27.311110   37.958075
# std     6.701921   73.549131
# min    12.972442 -122.431297
# 25%    24.476553   62.061043
# 50%    28.457523   77.026344
# 75%    29.197353   77.734322
# max    42.033363   86.933000

# %% [markdown]
# Using Folium Library for getting graph

# %%
import folium
latlon = [(23.667, 86.933),(37.773972, -122.431297) ,(37.54129, -77.434769) ,(29.749907, -95.358421), (32.715736, -117.161087),(38.624691, -90.184776) ,(29.854263, 77.888) ,(26.85, 80.949997) ,(12.972442, 77.580643), (28.535517, 77.391029) , (26.85, 80.949997), (28.457523,77.026344), (28.535517, 77.391029),(28.538336,-81.379234),(31.683, 76.117),(25.432571,81.851311),(28.457523, 77.026344), (42.033363,-87.8834) ,(18.530823, 73.847466), (12.972442, 77.580643),(12.972442, 77.580643), (25.612677, 85.158875),(28.457523, 77.026344),(26.85, 80.949997),(28.535517, 77.391029),(28.457523, 77.026344),(28.457523, 77.026344),(28.6448,77.216721), (23.02579, 72.58727),(20.462521,85.882988),(25.286106,51.534817),(40.866959,-74.417374),(28.36678,79.43167),(21.17024,72.831062),(25.612677,85.158875),(23.02579,72.58727),(21.17024,72.831062),(29.7559698,-95.3573194),(28.6263,77.2185)]
mapit = folium.Map( location=[23.667, 86.933], zoom_start=6 )
for coord in latlon:
    folium.Marker( location=[ coord[0], coord[1] ], fill_color='#43d9de', radius=8 ).add_to( mapit )

mapit
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
map_lucknow = folium.Map(location=[26.850000,80.949997],zoom_start=10)

##for lat,lng,borough,neighbourhood in zip(df2['latitude'],df2['longitude'], df['Name']):
##    label = '{}'.format( Name)
##    label = folium.Popup(label, parse_html=True)
##    folium.CircleMarker(
##    [lat,lng],
##    radius=5,
##    popup=label,
##    color='blue',
##    fill=True,
##    fill_color='#3186cc',
##    fill_opacity=0.7,
##    parse_html=False).add_to(map_lucknow)
map_lucknow
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Getting Graph using Folium Library

# %%
import folium
latlon = [(23.667, 86.933),(37.773972, -122.431297) ,(37.54129, -77.434769) ,(29.749907, -95.358421), (32.715736, -117.161087),(38.624691, -90.184776) ,(29.854263, 77.888) ,(26.85, 80.949997) ,(12.972442, 77.580643), (28.535517, 77.391029) , (26.85, 80.949997), (28.457523,77.026344), (28.535517, 77.391029),(28.538336,-81.379234),(31.683, 76.117),(25.432571,81.851311),(28.457523, 77.026344), (42.033363,-87.8834) ,(18.530823, 73.847466), (12.972442, 77.580643),(12.972442, 77.580643), (25.612677, 85.158875),(28.457523, 77.026344),(26.85, 80.949997),(28.535517, 77.391029),(28.457523, 77.026344),(28.457523, 77.026344),(28.6448,77.216721), (23.02579, 72.58727),(20.462521,85.882988),(25.286106,51.534817),(40.866959,-74.417374),(28.36678,79.43167),(21.17024,72.831062),(25.612677,85.158875),(23.02579,72.58727),(21.17024,72.831062),(29.7559698,-95.3573194),(28.6263,77.2185)]
mapit = folium.Map( location=[23.667, 86.933], zoom_start=6 )
for coord in latlon:
    folium.Marker( location=[ coord[0], coord[1] ], fill_color='#43d9de', radius=8 ).add_to( mapit )

mapit
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
